# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
content=requests.get("https://www.flipkart.com/gaming-laptops-store?otracker=nmenu_sub_Electronics_0_Gaming%20Laptops&otracker=nmenu_sub_Electronics_0_Gaming%20Laptops").text

# %%
soup=bs(content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.490897.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
prettify(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0db7423461df> in <module>
# ----> 1 prettify(soup)
#
# NameError: name 'prettify' is not defined

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>\n  <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>\n  <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.490897.css" rel="stylesheet"/>\n  <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">\n   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n   <meta content="website" property="og:type"/>\n   <meta content="Flipkart.com" name="og_site_
# ...

# %%
links=soup.find_all("link")

# %%
print (links)
# Out:
# [<link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>, <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>, <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.490897.css" rel="stylesheet"/>, <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>, <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# <!-- Appple Touch Icons -->
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
for links in soup.find_all("link"):
    print (links.get("href"))
# Out:
# https://rukminim1.flixcart.com
# https://img1a.flixcart.com
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.490897.css
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png
# https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico
# /osdd.xml?v=2
# /apple-touch-icon-57x57.png
# /apple-touch-icon-72x72.png
# /apple-touch-icon-114x114.png
# /apple-touch-icon-144x144.png
# /apple-touch-icon-57x57.png
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/css/MultiWidgetPage.chunk.a65ee6.css
# https://www.flipkart.com/gaming-laptops-store

# %%
for para in soup.find_all("p"):
    print(para.text)
# Out:
# Gaming Laptops have evolved in a big way over the years with the increasing power of the device and the decreasing size. Flipkart has lined up some of the best gaming laptops including MSI GV series laptop, Dell Inspiron Gaming Laptops, Acer Predator Helios, Alienware Gaming laptops and more for you to buy under exciting offers and discounts. One must consider factors like the GPU, with the NVIDIA GeForce being one of the best, the RAM, the CPU and the drive while looking to buy gaming laptops online. Be you a casual gamer or a hardcore gamer, Flipkart has exactly the specifications you are looking to have in a gaming laptop and you can zero in on what to buy very easily on this platform.
#
#
# ...

# %%
for images in soup.find_all("img"):
    print(images)
# Out:
# <img alt="Flipkart" class="_1e_EAo" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png" title="Flipkart" width="75"/>
# <img src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png" width="10"/>
# <img class="_2rIV_l" height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/>
# <img alt="MSI GS Core i7 8th Gen - (16 GB/512 GB SSD/Windows 10 Home/6 GB Graphics) GS65 8RE-084IN Gaming Laptop" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
# <img class="_2lQ_WZ" src="..."/>
# <img alt="Acer Nitro 5 Core i5 8th Gen - (8 GB + 16 GB Optane/1 TB HDD/Windows 10 Home/4 GB Graphics) AN515-52-593F Gaming Laptop" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
# <img class="_2lQ_WZ" src="..."/>
# ...

# %%
for links in soup.find_all("a"):
    print(links.get("href"))
# Out:
# /
# /plus
# /account/login?ret=/gaming-laptops-store%3Fotracker%3Dnmenu_sub_Electronics_0_Gaming%2520Laptops%26otracker%3Dnmenu_sub_Electronics_0_Gaming%2520Laptops
# /viewcart?otracker=Cart_Icon_Click
# /laptops/~msi-gaming-laptops/pr?sid=6bo,b5g
# /laptops/~dell-gaming-laptops-india/pr?sid=6bo,b5g
# /laptops/pr?sid=b5g&p[]=facets.serviceability%5B%5D%3Dtrue&otracker=categorytree
# /laptops/~gaming/pr?count=40&p%5B%5D=sort%3Dpopularity&sid=6bo%2Fb5g&wid=2.productCard.PMU_V2_2
# ...

# %%
for image in soup.find_all('img'):
    print(image['src']+'\n')
# Out:
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png
#
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png
#
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png
#
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ....flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
#
# ...
